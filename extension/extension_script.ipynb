# %%
import pandas as pd

# %%
data = pd.read_csv('sample_data/train_sent_emo.csv')
data.head()
# Out:
#    Sr No.                                          Utterance          Speaker  \
# 0       1  also I was the point person on my company’s tr...         Chandler
# 1       2                   You must’ve had your hands full.  The Interviewer
# 2       3                            That I did. That I did.         Chandler
# 3       4      So let’s talk a little bit about your duties.  The Interviewer
# 4       5                             My duties?  All right.         Chandler
#
#     Emotion Sentiment  Dialogue_ID  Utterance_ID  Season  Episode  \
# 0   neutral   neutral            0             0       8       21
# 1   neutral   neutral            0             1       8       21
# 2   neutral   neutral            0             2       8       21
# 3   neutral   neutral            0             3       8       21
# 4  surprise  positive            0             4       8       21
#
#       StartTime       EndTime
# 0  00:16:16,059  00:16:21,731
# 1  00:16:21,940  00:16:23,442
# ...

# %%
names = pd.read_csv('sample_data/GenderNames300.csv')
names.head()
# Out:
#    Unnamed: 0 Male_Names Male_Label Female_Names Female_Label Neutral  \
# 0           0      James          M         Mary            F     Ace
# 1           1       John          M       Camila            F   Aiden
# 2           2     Robert          M         Luna            F    Alex
# 3           3    Michael          M     Scarlett            F   Aster
# 4           4    William          M      Abigail            F   Auden
#
#   Neutral_Label
# 0             N
# 1             N
# 2             N
# 3             N
# 4             N

# %%
selected = data.loc[data['Dialogue_ID'] <= 100]

# selected_2 = data.loc[data['Dialogue_ID'] <= 530]

# %%
selected.to_csv('sample_data/original_1000.csv')

# %%
hmap = {}

idx = 0
lst = []
for _, row in selected.iterrows():
  if row['Speaker'] in hmap:
    lst.append(hmap[row['Speaker']])
  else:
    hmap[row['Speaker']] = names['Neutral'].iloc[idx]
    idx += 1
    lst.append(hmap[row['Speaker']])

selected['Speaker'] = lst
# Out:
# <ipython-input-42-d249ace7cf18>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected['Speaker'] = lst

# %%
selected.to_csv('sample_data/all_neutral_1000.csv')

# %%
selected = data.loc[data['Dialogue_ID'] <= 100]

selected.to_csv('sample_data/100_dialogues.csv')

# df.loc[(df['Discount'] >= 1000) & (df['Discount'] <= 2000)]



# for idx, row in data.iterrows():
#   if row['Dialogue_ID'] > 100:
#     continue
#   print(row)
#   # if row['Dialogue_ID'] > 100:
#   #   continue
#   # print(row)

# %%
names = pd.read_csv('sample_data/GenderNames.csv')
names.head()
# Out:
#    Unnamed: 0 Male_Names Male_Label Female_Names Female_Label Neutral  \
# 0           0      James          M         Mary            F     Ace
# 1           1       John          M     Patricia            F   Aiden
# 2           2     Robert          M        Linda            F    Alex
# 3           3    Michael          M      Barbara            F   Aster
# 4           4    William          M    Elizabeth            F   Auden
#
#   Neutral_Label
# 0             N
# 1             N
# 2             N
# 3             N
# 4             N

# %%
set(selected_2['Speaker'])
# Out:
# {'1st Customer',
#  '2nd Customer',
#  '3rd Customer',
#  'A Female Student',
#  'All',
#  'Annabelle',
#  'Barry',
#  'Bernice',
#  'Bob',
#  'Bobby',
#  'Bonnie',
#  'Both',
#  'Caitlin',
#  'Carl',
#  'Carol',
#  'Cassie',
#  'Chandler',
#  'Charlie',
#  'Charlton Heston',
#  'Chloe',
#  'Cliff',
#  'Commercial',
#  'Customer',
#  'Dana',
#  'Danny',
#  'David',
#  'Dina',
#  'Director',
#  'Doug',
#  'Dr. Baldhara',
#  'Dr. Green',
#  'Dr. Johnson',
#  'Dr. Ledbetter',
#  'Dr. Leedbetter',
#  'Dr. Long',
#  'Dr. Miller',
#  'Dr. Rhodes',
#  'Drunken Gambler',
#  'Duncan',
#  'Earl',
#  'Elizabeth',
#  'Emeril',
#  'Emily',
#  'Eric',
#  'Fireman No. 3',
#  'Flight Attendant',
#  'Frank',
#  'Front Desk Clerk',
#  'Gary',
#  'Gary Collins',
#  'Gunther',
#  'Guru Saj',
#  'Guy',
#  'Hitchhiker',
#  'Isabella',
#  'Issac',
#  'Jade',
#  'Jake',
#  'Jane',
#  'Janice',
#  'Janine',
#  'Jason',
#  'Jester',
#  'Jill',
#  'Jim',
#  'Joanna',
#  'Joanne',
#  'Joey',
# ...

# %%
temp_df = pd.DataFrame
temp_df['original'] = list(set(selected_2['Speaker']))
temp_df.to_csv('original_mapping.csv')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-7892205f3aef> in <module>
#       1 temp_df = pd.DataFrame
# ----> 2 temp_df['original'] = list(set(selected_2['Speaker']))
#       3 temp_df.to_csv('original_mapping.csv')
#
# TypeError: 'type' object does not support item assignment

# %%
# female to male
female_to_male = { 'Caitlin': 'James', 'Carol': 'John', 'Cassie': 'Robert', 'Dina': 'Michael', 'Dr. Long': 'William', 'Elizabeth': 'David', 'Emily': 'Richard', 'Jade' : 'Charles', 'Janice': 'Joseph', 'Jill': 'Thomas', 'Joanna': 'Christopher', 'Kate': 'Paul', 'Kim': 'Mark', 'Krista': 'Donald', 'Mona': 'George', 'Monica': 'Kenneth', 'Nancy': 'Steven', 'Phoebe': 'Edward', 'Rachel': 'Brian'}

# %%
# male to neutral
male_to_neutral = {'Bob': 'Ace', 'Bobby': 'Aiden', 'Chandler': 'Alex', 'Charlie': 'Aster', 'Charlton Heston': 'Auden', 'Danny': 'Ellis', 'Doug': 'Honor', 'Dr. Rhodes': 'Jody', 'Guru Saj': 'Justice', 'Joey': 'Onyx', 'Joshua': 'Phoenix', 'Mr. Franklin': 'Reese', 'Mr. Treeger': 'Scout', 'Mr. Tribbiani': 'Shiloh', 'Paul': 'Teagan', 'Peter': 'Yoshi', 'Professore Clerk': 'Andy', 'Richard': 'Ariel', 'Ross': 'Brook', 'Sergei': 'Cameron', 'Stevens': 'Charlie', 'Tony': 'Demi', 'Wayne': 'Devin'}

# %%
len(female_to_male) + len(male_to_neutral)
# Out:
# 42

# %%
lst = []

for _, row in selected.iterrows():
  if row['Speaker'] in female_to_male:
    lst.append(female_to_male[row['Speaker']])
    #print('test1')
    #print(row['Speaker'], female_to_male[row['Speaker']])
    #print('before', row['Speaker'])
    #row['Speaker'] = female_to_male[row['Speaker']
                                    
    #print('after', row['Speaker'])
  
  elif row['Speaker'] in male_to_neutral:
    lst.append(male_to_neutral[row['Speaker']])
    #print(row['Speaker'], male_to_neutral[row['Speaker']])
    #row['Speaker'] = male_to_neutral[row['Speaker']]
  else:
    lst.append(row['Speaker'])

selected['Speaker'] = lst
    
selected.to_csv('sample_data/female_to_male.csv')
# Out:
# <ipython-input-89-4d48367f0d27>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected['Speaker'] = lst

# %%
#selected.to_csv('sample_data/female_to_male.csv')

# %%
names = pd.read_csv('sample_data/GenderNames.csv')
names.head()
# Out:
#    Unnamed: 0 Male_Names Male_Label Female_Names Female_Label Neutral  \
# 0           0      James          M         Mary            F     Ace
# 1           1       John          M     Patricia            F   Aiden
# 2           2     Robert          M        Linda            F    Alex
# 3           3    Michael          M      Barbara            F   Aster
# 4           4    William          M    Elizabeth            F   Auden
#
#   Neutral_Label
# 0             N
# 1             N
# 2             N
# 3             N
# 4             N

# %%
names['Female_Names'].iloc[0]
# Out:
# 'Mary'

# %%
neutral_map = {}

idx = 0
neutral_lst = []
for _, row in data.iterrows():
  if row['Speaker'] in neutral_map:
    neutral_lst.append(neutral_map[row['Speaker']])
  else:
    neutral_map[row['Speaker']] = names['Female_Names'].iloc[idx]
    idx += 1
    neutral_lst.append(neutral_map[row['Speaker']])

data['Speaker'] = neutral_lst
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-93-ec57fdaf344c> in <module>
#       7     neutral_lst.append(neutral_map[row['Speaker']])
#       8   else:
# ----> 9     neutral_map[row['Speaker']] = names['Female_Names'].iloc[idx]
#      10     idx += 1
#      11     neutral_lst.append(neutral_map[row['Speaker']])
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1564
#    1565             # validate the location
# -> 1566             self._validate_integer(key, axis)
#    1567
# ...

# %%
data.to_csv('sample_data/all_neutral.csv')
